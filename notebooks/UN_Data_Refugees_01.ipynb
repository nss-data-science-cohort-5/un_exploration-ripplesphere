# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
refugees_df = pd.read_csv("../data/UNdata_refugees.csv", skipfooter=3, engine='python')
ref_df = refugees_df[["Country or territory of asylum or residence", "Country or territory of origin", 
                      "Year", "Refugees<sup>*</sup>"]]
ref_df = ref_df.rename({"Country or territory of asylum or residence": "asylum", 
                        "Country or territory of origin": "origin", "Refugees<sup>*</sup>": "refugees"}, axis="columns")
ref_df["Year"] = ref_df["Year"].astype(int)

# %%
plt.plot(ref_df.groupby("Year").sum())
plt.title("Total Refugees by Year 1975-2016 (in millions)")
print()

# %%
# Number of refugees outflow sorted by country
ref_df[["origin", "refugees"]][ref_df["origin"] != "Various".groupby("origin").sum().\
    sort_values("refugees", ascending=False).head(20)
# Out:
#                            refugees
# origin
# Afghanistan             125836802.0
# Iraq                     26456503.0
# Ethiopia                 23286613.0
# Somalia                  19003975.0
# Syrian Arab Rep.         17662833.0
# Sudan                    15058675.0
# Viet Nam                 14839294.0
# Angola                   13013851.0
# Rwanda                   12600732.0
# Burundi                  12209817.0
# Dem. Rep. of the Congo   10451074.0
# Mozambique                8718739.0
# Liberia                   8427746.0
# Bosnia and Herzegovina    8361632.0
# Eritrea                   7792848.0
# Western Sahara            5313335.0
# Myanmar                   4806584.0
# State of Palestine        4571018.0
# Croatia                   4166761.0
# Azerbaijan                4054485.0

# %%
# Number of refugees taken in sorted by country
ref_df[["asylum", "refugees"]].groupby("asylum").sum().\
    sort_values("refugees", ascending=False).head(20)
# Out:
#                                           refugees
# asylum
# Pakistan                                67983474.0
# Islamic Rep. of Iran                    66945262.0
# Germany                                 25914275.0
# United States                           20045105.0
# Sudan                                   18718424.0
# Dem. Rep. of the Congo                  17194654.0
# United Rep. of Tanzania                 14451697.0
# Somalia                                 11534802.0
# China                                   11025639.0
# Ethiopia                                10943119.0
# Uganda                                   8667635.0
# Kenya                                    8596198.0
# Turkey                                   8174011.0
# Syrian Arab Rep.                         7358228.0
# Serbia (and Kosovo: S/RES/1244 (1999))   7005100.0
# France                                   6991110.0
# Guinea                                   6578080.0
# United Kingdom                           6556363.0
# Lebanon                                  5911194.0
# Malawi                                   5817224.0

# %%
ref_df[ref_df["origin"] == "Various"].sort_values("refugees", ascending=False).head(20)
# Out:
#               asylum   origin  Year   refugees
# 89433        Germany  Various  1993  1396000.0
# 90634        Germany  Various  1992  1208000.0
# 87915        Germany  Various  1994   984000.0
# 86197        Germany  Various  1995   929100.0
# 76217        Germany  Various  1999   925500.0
# 84249        Germany  Various  1996   919000.0
# 69798        Germany  Various  2001   879000.0
# 73094        Germany  Various  2000   876000.0
# 79199        Germany  Various  1998   849200.0
# 91405        Germany  Various  1991   793000.0
# 81843        Germany  Various  1997   788000.0
# 92057        Germany  Various  1990   784000.0
# 96048        Various  Various  1975   749120.0
# 95558  United States  Various  1979   734000.0
# 95708  United States  Various  1978   734000.0
# 95778        Lebanon  Various  1977   700000.0
# 95901        Lebanon  Various  1976   700000.0
# 95836  United States  Various  1977   684700.0
# 94723  United States  Various  1983   655532.0
# 94461  United States  Various  1984   626909.0

# %%
ref_df.groupby(["origin","asylum"]).sum()
# Out:
#                                       Year  refugees
# origin      asylum
# Afghanistan Algeria                  10070      10.0
#             Argentina                12081      18.0
#             Australia                42126  124977.0
#             Austria                  38133  120962.0
#             Azerbaijan               42126    5967.0
# ...                                    ...       ...
# Zimbabwe    United Kingdom           58058  143482.0
#             United Rep. of Tanzania   5961     161.0
#             United States            40125   18379.0
#             Uruguay                  18108       9.0
#             Zambia                   29991  100644.0
#
# [7565 rows x 2 columns]

# %%
ref_df[(ref_df["origin"] == "Afghanistan") & (ref_df["refugees"] > 1000) & 
       (ref_df["Year"] == 2016)].sort_values("refugees", ascending=False)
# Out:
#                     asylum       origin  Year   refugees
# 3550              Pakistan  Afghanistan  2016  1352160.0
# 2440  Islamic Rep. of Iran  Afghanistan  2016   951142.0
# 1842               Germany  Afghanistan  2016    46292.0
# 297                Austria  Afghanistan  2016    20220.0
# 4387                Sweden  Afghanistan  2016    16558.0
# 2474                 Italy  Afghanistan  2016    16033.0
# 4928        United Kingdom  Afghanistan  2016     9752.0
# 169              Australia  Afghanistan  2016     9217.0
# 2279                 India  Afghanistan  2016     7693.0
# 1649                France  Afghanistan  2016     7685.0
# 3448                Norway  Afghanistan  2016     6568.0
# 3218           Netherlands  Afghanistan  2016     5791.0
# 4522           Switzerland  Afghanistan  2016     5675.0
# 2308             Indonesia  Afghanistan  2016     4379.0
# 4779                Turkey  Afghanistan  2016     3423.0
# 447                Belgium  Afghanistan  2016     3201.0
# 805                 Canada  Afghanistan  2016     3177.0
# 4677            Tajikistan  Afghanistan  2016     2711.0
# 1351               Denmark  Afghanistan  2016     2364.0
# 1555               Finland  Afghanistan  2016     2216.0
# 2031                Greece  Afghanistan  2016     2127.0
# 4860               Ukraine  Afghanistan  2016     1497.0
# 5089         United States  Afghanistan  2016     1466.0
# 4648      Syrian Arab Rep.  Afghanistan  2016     1186.0
# 2177               Hungary  Afghanistan  2016     1008.0

# %%
plt.plot(ref_df[(ref_df["origin"] == "Afghanistan") & (ref_df["refugees"] > 1000)].\
         sort_values("refugees", ascending=False)[["Year","refugees"]].\
        groupby("Year").sum().sort_values("Year"))

# %%
plt.plot(ref_df[(ref_df["origin"] == "Iraq") & (ref_df["refugees"] > 1000)].\
         sort_values("refugees", ascending=False)[["Year","refugees"]].\
        groupby("Year").sum().sort_values("Year"))
