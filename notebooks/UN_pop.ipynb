# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import StrMethodFormatter

# %matplotlib inline

# %%
pop_df = pd.read_csv("../data/WPP2019_TotalPopulationBySex.csv")

# %%
pop_df[pop_df["Location"] == "Afghanistan"]
# Out:
#      LocID     Location  VarID      Variant  Time  MidPeriod    PopMale  \
# 0        4  Afghanistan      2       Medium  1950     1950.5   4099.243
# 1        4  Afghanistan      2       Medium  1951     1951.5   4134.756
# 2        4  Afghanistan      2       Medium  1952     1952.5   4174.450
# 3        4  Afghanistan      2       Medium  1953     1953.5   4218.336
# 4        4  Afghanistan      2       Medium  1954     1954.5   4266.484
# ..     ...          ...    ...          ...   ...        ...        ...
# 879      4  Afghanistan    207  Lower 95 PI  2080     2080.5  25186.927
# 880      4  Afghanistan    207  Lower 95 PI  2085     2085.5  23935.801
# 881      4  Afghanistan    207  Lower 95 PI  2090     2090.5  22417.422
# 882      4  Afghanistan    207  Lower 95 PI  2095     2095.5  20883.941
# 883      4  Afghanistan    207  Lower 95 PI  2100     2100.5  19397.112
#
#      PopFemale   PopTotal  PopDensity
# 0     3652.874   7752.117      11.874
# ...

# %%
afgh_df = pop_df[(pop_df["Location"] == "Afghanistan") & (pop_df["Time"] < 2017)][["PopTotal", "Time"]]
afgh_df["Time"] = afgh_df["Time"].astype(int)

# %%
plt.plot(afgh_df["PopTotal"])

# %%
afgh_df["Time"] = afgh_df["Time"].astype(int)

# %%
afgh_df
# Out:
#      PopTotal  Time
# 0    7752.117  1950
# 1    7840.151  1951
# 2    7935.996  1952
# 3    8039.684  1953
# 4    8151.316  1954
# ..        ...   ...
# 62  31161.378  2012
# 63  32269.592  2013
# 64  33370.804  2014
# 65  34413.603  2015
# 66  35383.028  2016
#
# [67 rows x 2 columns]
